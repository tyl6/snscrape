# %%
import pandas as pd
df = pd.read_json(r'D:/Produktivitas/Python/Snscrape/text-query-tweets.json', lines=True, encoding='utf-16')
df.to_csv(r'D:/Produktivitas/Python/Snscrape/text-query-tweets.csv')
df
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 5608  snscrape.modules.twitter.Tweet
# 5609  snscrape.modules.twitter.Tweet
# 5610  snscrape.modules.twitter.Tweet
# 5611  snscrape.modules.twitter.Tweet
# 5612  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/DiskominfoMKS/status/15759...
# 1     https://twitter.com/DiskominfoMKS/status/15759...
# 2     https://twitter.com/DiskominfoMKS/status/15759...
# 3     https://twitter.com/DiskominfoMKS/status/15759...
# 4     https://twitter.com/DiskominfoMKS/status/15759...
# ...                                                 ...
# 5608  https://twitter.com/DiskominfoMKS/status/15426...
# 5609  https://twitter.com/DiskominfoMKS/status/15426...
# ...
